# %%
import numpy as np 
import pandas as pd 
import scipy.stats as stats

# %%
filelocation = "E:\Rnw\maths\Exam\Derivable Judgement\health_dataset.csv"
df = pd.read_csv(filelocation)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\R'
# <>:1: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\parth\AppData\Local\Temp\ipykernel_8212\2720648920.py:1: SyntaxWarning: invalid escape sequence '\R'
#   filelocation = "E:\Rnw\maths\Exam\Derivable Judgement\health_dataset.csv"

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of     record_id  age  weight  gender region smoking_status exercise_frequency  \
# 0        RID1   56      76    Male  North         Smoker             Rarely
# 1        RID2   69      99    Male  South  Former Smoker             Rarely
# 2        RID3   46      53  Female   East  Former Smoker              Never
# 3        RID4   32      85    Male   East  Former Smoker              Daily
# 4        RID5   60      79    Male  North  Former Smoker              Never
# ..        ...  ...     ...     ...    ...            ...                ...
# 295    RID296   18      57    Male  South     Non-Smoker             Rarely
# 296    RID297   65      56    Male  South         Smoker              Never
# 297    RID298   29      75    Male   East     Non-Smoker             Weekly
# 298    RID299   22      90  Female   West     Non-Smoker              Never
# 299    RID300   54      46    Male   East     Non-Smoker             Rarely
#
# ...

# %% [markdown]
# ***Hypothesis 1: BMI and Hypertension***
#
# Null Hypothesis (H₀): There is no significant relationship between BMI and hypertension status.
#
# Alternative Hypothesis (H₁): Individuals with higher BMI are more likely to have hypertension.
#
# ***Hypothesis 2: Exercise Frequency and Blood Pressure***
#
# Null Hypothesis (H₀): Exercise frequency has no effect on blood pressure levels.
#
# Alternative Hypothesis (H₁): Individuals who exercise more frequently have lower blood pressure levels.
