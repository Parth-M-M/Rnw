# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib as mlb

# %% [markdown]
# **Task 1: Notebook Structure & Data Loading**

# %%
fileloc = r"C:\Users\parth\Desktop\Ecommerce_Logistics_and_Delivery_Gigantic_Dataset - Ecommerce_Logistics_and_Delivery_Gigantic_Dataset.csv.csv"

# %%
df = pd.read_csv(fileloc)

print(df.head(5))
# Out:
#    Shipment_ID  Order_Date Region       City Delivery_Partner Shipping_Mode  \
# 0       900000  2022-09-05  North  Ahmedabad     Ecom Express      Standard
# 1       900001  2023-03-29   West  Ahmedabad         BlueDart      Standard
# 2       900002  2022-03-23  South  Hyderabad         BlueDart      Standard
# 3       900003  2024-01-25   West  Hyderabad     Ecom Express      Standard
# 4       900004  2023-11-11  South     Mumbai     Ecom Express      Standard
#
#    Delivery_Time_Days  Order_Value Delivery_Status  Customer_Rating
# 0                 8.0    171575.41       Delivered              4.0
# 1                10.0      8628.10         Delayed              3.0
# 2                12.0    161353.25       Cancelled              3.0
# 3                14.0     57509.48         Delayed              2.0
# 4                14.0    154628.04       Delivered              1.0

# %% [markdown]
# *Ecommerce_Logistics_and_Delivery_Gigantic_Dataset loaded and can be viewed*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73500 entries, 0 to 73499
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Shipment_ID         73500 non-null  int64
#  1   Order_Date          73500 non-null  object
#  2   Region              58743 non-null  object
#  3   City                65245 non-null  object
#  4   Delivery_Partner    65962 non-null  object
#  5   Shipping_Mode       73500 non-null  object
#  6   Delivery_Time_Days  68652 non-null  float64
#  7   Order_Value         73500 non-null  float64
#  8   Delivery_Status     69884 non-null  object
#  9   Customer_Rating     66117 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#          Shipment_ID  Delivery_Time_Days    Order_Value  Customer_Rating
# count   73500.000000        68652.000000   73500.000000     66117.000000
# mean   935016.716612            7.541761   99924.325369         3.349577
# std     20199.507118            4.041246   57650.901131         1.165733
# min    900000.000000            1.000000     302.070000         1.000000
# 25%    917524.750000            4.000000   49895.900000         3.000000
# 50%    935034.500000            8.000000   99908.880000         3.000000
# 75%    952495.250000           11.000000  149806.210000         4.000000
# max    969999.000000           14.000000  199999.600000         5.000000

# %%
pd.isnull(df)
# Out:
#        Shipment_ID  Order_Date  Region   City  Delivery_Partner  \
# 0            False       False   False  False             False
# 1            False       False   False  False             False
# 2            False       False   False  False             False
# 3            False       False   False  False             False
# 4            False       False   False  False             False
# ...            ...         ...     ...    ...               ...
# 73495        False       False   False  False             False
# 73496        False       False   False  False             False
# 73497        False       False   False  False             False
# 73498        False       False   False  False             False
# 73499        False       False    True   True              True
#
#        Shipping_Mode  Delivery_Time_Days  Order_Value  Delivery_Status  \
# 0              False               False        False            False
# ...

# %%
df.tail()
# Out:
#        Shipment_ID  Order_Date   Region     City Delivery_Partner  \
# 73495       901870  2022-08-09     East  Kolkata     Ecom Express
# 73496       915961  2023-07-20     West     Pune        Delhivery
# 73497       909351  2023-09-17    South   Mumbai     Ecom Express
# 73498       966364  2021-10-20  Central     Pune         BlueDart
# 73499       909712  2022-03-27      NaN      NaN              NaN
#
#       Shipping_Mode  Delivery_Time_Days  Order_Value Delivery_Status  \
# 73495       Express                 7.0      7879.04       Delivered
# 73496       Express                 6.0    145610.57       Delivered
# 73497       Express                14.0    140215.59       Delivered
# 73498      Same-Day                 8.0    132471.00         Delayed
# 73499      Standard                13.0     37043.44       Delivered
#
#        Customer_Rating
# 73495              4.0
# 73496              3.0
# 73497              3.0
# 73498              5.0
# 73499              4.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73500 entries, 0 to 73499
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Shipment_ID         73500 non-null  int64
#  1   Order_Date          73500 non-null  object
#  2   Region              58743 non-null  object
#  3   City                65245 non-null  object
#  4   Delivery_Partner    65962 non-null  object
#  5   Shipping_Mode       73500 non-null  object
#  6   Delivery_Time_Days  68652 non-null  float64
#  7   Order_Value         73500 non-null  float64
#  8   Delivery_Status     69884 non-null  object
#  9   Customer_Rating     66117 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 5.6+ MB

# %%
sns.displot(df['Region'])

# %%
df['Delivery_Status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Delivery_Status'>

# %%
sns.distplot(df['Order_Value'])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_15716\2097264440.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Order_Value'])
# <Axes: xlabel='Order_Value', ylabel='Density'>

# %%
df['Delivery_Time_Days'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Order_Date'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Order_Date'>

# %%
df['Delivery_Partner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Delivery_Partner'>

# %%
sns.scatterplot(data=df, x='Delivery_Partner', y='Delivery_Time_Days')
# Out:
# <Axes: xlabel='Delivery_Partner', ylabel='Delivery_Time_Days'>

# %%
sns.scatterplot(data=df, x='Shipping_Mode', y='Customer_Rating',hue = df['Shipping_Mode'])
# Out:
# <Axes: xlabel='Shipping_Mode', ylabel='Customer_Rating'>

# %%
sns.lineplot(data = df , x = 'Order_Date' , y = 'Order_Value'   )
# Out:
# <Axes: xlabel='Order_Date', ylabel='Order_Value'>

# %%
df['City'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
df['Region'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
sns.barplot(data  = df ,  x = df['Region'], y = df['Order_Value'] , hue = df['Delivery_Partner'])
# Out:
# <Axes: xlabel='Region', ylabel='Order_Value'>

# %%
sns.barplot(data  = df ,  x = df['Delivery_Partner'], y = df['Delivery_Time_Days'] , hue = df['Delivery_Status'])
# Out:
# <Axes: xlabel='Delivery_Partner', ylabel='Delivery_Time_Days'>

# %%
sns.barplot(data  = df ,  x = df['Delivery_Partner'], y = df['Delivery_Time_Days'] , hue = df['Shipping_Mode'])
# Out:
# <Axes: xlabel='Delivery_Partner', ylabel='Delivery_Time_Days'>

# %%
sns.scatterplot(data=df, x='Shipping_Mode', y='Order_Value')
# Out:
# <Axes: xlabel='Shipping_Mode', ylabel='Order_Value'>

# %% [markdown]
#                                                                       ***Summary***
# 1. in Eda process 20% of data is missing
# 2. from amount from 2021 to 2024 is increasing but avg order value stays at 100000 so the products which company is selling is getting smaller in value therefore increaseing logistic preasure per day compare to 2021
# 3. in delivery time our delivery  partners our collecting orders of batch delivery to save cost but its affecting are time in completing are order
# 4. it is suggest to build warehouse center with most common selling product in top cities to decerese presure on logistics there by decreasing delivery time
