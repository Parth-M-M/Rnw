# %%
! pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in e:\Rnw\dataprofiler\Lib\site-packages (from ucimlrepo) (2.3.3)
# Requirement already satisfied: certifi>=2020.12.5 in e:\Rnw\dataprofiler\Lib\site-packages (from ucimlrepo) (2026.1.4)
# Requirement already satisfied: numpy>=1.26.0 in e:\Rnw\dataprofiler\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\Rnw\dataprofiler\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\Rnw\dataprofiler\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\Rnw\dataprofiler\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.3)
# Requirement already satisfied: six>=1.5 in e:\Rnw\dataprofiler\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7
# [notice] A new release of pip is available: 26.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
student_performance = fetch_ucirepo(id=320)

# %%
student_performance.to_csv("student_performance.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 student_performance.to_csv("student_performance.csv", index=False)
#
# TypeError: 'NoneType' object is not callable
