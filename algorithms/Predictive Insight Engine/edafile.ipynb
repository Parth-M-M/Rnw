# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
filelocation = r"E:\Rnw\algorithms\Predictive Insight Engine\RealEstate.csv"
df = pd.read_csv(filelocation)
df.head()
# Out:
#    house_id  area_sqft  bedrooms  bathrooms  location_score  age_years  \
# 0    100001       1973         5          4             7.6         23
# 1    100002       1560         3          3             6.3         13
# 2    100003       2071         4          3             5.8          9
# 3    100004       2640         5          3             7.7         12
# 4    100005       1498         3          3             3.8         15
#
#    distance_city_km  lot_size_sqft  has_garage  has_pool  \
# 0              11.9           5220           1         0
# 1              15.8           3882           1         0
# 2              21.1           4488           0         0
# 3               7.9           3614           1         1
# 4              24.0           2663           0         0
#
#    renovation_years_ago  house_price_inr
# 0                     0         40275084
# 1                    13         26812029
# 2                     9         29315677
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4200 entries, 0 to 4199
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   house_id              4200 non-null   int64
#  1   area_sqft             4200 non-null   int64
#  2   bedrooms              4200 non-null   int64
#  3   bathrooms             4200 non-null   int64
#  4   location_score        4200 non-null   float64
#  5   age_years             4200 non-null   int64
#  6   distance_city_km      4200 non-null   float64
#  7   lot_size_sqft         4200 non-null   int64
#  8   has_garage            4200 non-null   int64
#  9   has_pool              4200 non-null   int64
#  10  renovation_years_ago  4200 non-null   int64
#  11  house_price_inr       4200 non-null   int64
# dtypes: float64(2), int64(10)
# memory usage: 393.9 KB

# %%
df.describe()
# Out:
#             house_id    area_sqft     bedrooms    bathrooms  location_score  \
# count    4200.000000  4200.000000  4200.000000  4200.000000     4200.000000
# mean   102100.500000  1667.357381     3.696667     2.827381        5.611429
# std      1212.579894   630.336132     1.574199     1.153585        2.140880
# min    100001.000000   450.000000     1.000000     1.000000        1.000000
# 25%    101050.750000  1226.750000     3.000000     2.000000        4.000000
# 50%    102100.500000  1660.000000     4.000000     3.000000        5.700000
# 75%    103150.250000  2084.250000     5.000000     4.000000        7.300000
# max    104200.000000  4202.000000     7.000000     6.000000       10.000000
#
#          age_years  distance_city_km  lot_size_sqft   has_garage     has_pool  \
# count  4200.000000       4200.000000    4200.000000  4200.000000  4200.000000
# mean     23.829524         18.186167    3366.329048     0.642381     0.096190
# ...

# %%
missing_percentage = df.isnull().mean() * 100
missing_percentage
# Out:
# house_id                0.0
# area_sqft               0.0
# bedrooms                0.0
# bathrooms               0.0
# location_score          0.0
# age_years               0.0
# distance_city_km        0.0
# lot_size_sqft           0.0
# has_garage              0.0
# has_pool                0.0
# renovation_years_ago    0.0
# house_price_inr         0.0
# dtype: float64

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df)
profile.to_file("realestateeda.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 92.78it/s]

# %%
coll = df.columns
coll
# Out:
# Index(['house_id', 'area_sqft', 'bedrooms', 'bathrooms', 'location_score',
#        'age_years', 'distance_city_km', 'lot_size_sqft', 'has_garage',
#        'has_pool', 'renovation_years_ago', 'house_price_inr'],
#       dtype='object')

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df["area_sqft"], kde=True)
plt.title("area_sqft Distribution")
plt.show()

sns.histplot(df["bedrooms"], kde=True)
plt.title("bedrooms Distribution")
plt.show()

sns.histplot(df["bathrooms"], kde=True)
plt.title("bathrooms Distribution")
plt.show()

sns.histplot(df["location_score"], kde=True)
plt.title("location_score Distribution")
plt.show()

sns.histplot(df["age_years"], kde=True)
plt.title("age_years Distribution")
plt.show()

sns.histplot(df["distance_city_km"], kde=True)
plt.title("distance_city_km Distribution")
plt.show()

sns.histplot(df["lot_size_sqft"], kde=True)
plt.title("lot_size_sqft Distribution")
plt.show()

sns.histplot(df["has_garage"], kde=True)
plt.title("has_garage Distribution")
plt.show()

sns.histplot(df["has_pool"], kde=True)
plt.title("has_pool Distribution")
plt.show()

sns.histplot(df["renovation_years_ago"], kde=True)
plt.title("renovation_years_ago Distribution")
plt.show()


sns.histplot(df["house_price_inr"], kde=True)
plt.title("house_price_inr Distribution")
plt.show()

# %%
coll
# Out:
# Index(['house_id', 'area_sqft', 'bedrooms', 'bathrooms', 'location_score',
#        'age_years', 'distance_city_km', 'lot_size_sqft', 'has_garage',
#        'has_pool', 'renovation_years_ago', 'house_price_inr'],
#       dtype='object')

# %%
sns.boxplot(data=df[coll[1]])
plt.title(df[coll[1]].name)
plt.show()

sns.boxplot(data=df[coll[2]])
plt.title(df[coll[2]].name)
plt.show()

sns.boxplot(data=df[coll[3]])
plt.title(df[coll[3]].name)
plt.show()

sns.boxplot(data=df[coll[4]])
plt.title(df[coll[4]].name)
plt.show()

sns.boxplot(data=df[coll[5]])
plt.title(df[coll[5]].name)
plt.show()

sns.boxplot(data=df[coll[6]])
plt.title(df[coll[6]].name)
plt.show()

sns.boxplot(data=df[coll[7]])
plt.title(df[coll[7]].name)
plt.show()

sns.boxplot(data=df[coll[10]])
plt.title(df[coll[10]].name)
plt.show()

# %%
coll
# Out:
# Index(['house_id', 'area_sqft', 'bedrooms', 'bathrooms', 'location_score',
#        'age_years', 'distance_city_km', 'lot_size_sqft', 'has_garage',
#        'has_pool', 'renovation_years_ago', 'house_price_inr'],
#       dtype='object')

# %%
coll_name = "area_sqft"

Q1 = df[coll_name].quantile(0.25)
Q3 = df[coll_name].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df[coll_name] = np.where(df[coll_name] > upper, upper, df[coll_name])
df[coll_name] = np.where(df[coll_name] < lower, lower, df[coll_name])

sns.boxplot(data=df[coll_name])
plt.title(df[coll_name].name)
plt.show()

# %%
coll_name = "age_years"

Q1 = df[coll_name].quantile(0.25)
Q3 = df[coll_name].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df[coll_name] = np.where(df[coll_name] > upper, upper, df[coll_name])
df[coll_name] = np.where(df[coll_name] < lower, lower, df[coll_name])

sns.boxplot(data=df[coll_name])
plt.title(df[coll_name].name)
plt.show()

# %%
coll_name = "age_years"

Q1 = df[coll_name].quantile(0.25)
Q3 = df[coll_name].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df[coll_name] = np.where(df[coll_name] > upper, upper, df[coll_name])
df[coll_name] = np.where(df[coll_name] < lower, lower, df[coll_name])

sns.boxplot(data=df[coll_name])
plt.title(df[coll_name].name)
plt.show()

# %%
coll_name = "distance_city_km"

Q1 = df[coll_name].quantile(0.25)
Q3 = df[coll_name].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df[coll_name] = np.where(df[coll_name] > upper, upper, df[coll_name])
df[coll_name] = np.where(df[coll_name] < lower, lower, df[coll_name])

sns.boxplot(data=df[coll_name])
plt.title(df[coll_name].name)
plt.show()

# %%
coll
# Out:
# Index(['house_id', 'area_sqft', 'bedrooms', 'bathrooms', 'location_score',
#        'age_years', 'distance_city_km', 'lot_size_sqft', 'has_garage',
#        'has_pool', 'renovation_years_ago', 'house_price_inr'],
#       dtype='object')

# %%
coll_name = "lot_size_sqft"

Q1 = df[coll_name].quantile(0.25)
Q3 = df[coll_name].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df[coll_name] = np.where(df[coll_name] > upper, upper, df[coll_name])
df[coll_name] = np.where(df[coll_name] < lower, lower, df[coll_name])

sns.boxplot(data=df[coll_name])
plt.title(df[coll_name].name)
plt.show()

# %%
coll_name = "renovation_years_ago"

Q1 = df[coll_name].quantile(0.25)
Q3 = df[coll_name].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df[coll_name] = np.where(df[coll_name] > upper, upper, df[coll_name])
df[coll_name] = np.where(df[coll_name] < lower, lower, df[coll_name])

sns.boxplot(data=df[coll_name])
plt.title(df[coll_name].name)
plt.show()

# %%
from scipy.stats import boxcox

df['area_sqft'], _ = boxcox(df['area_sqft'])

sns.histplot(df["area_sqft"], kde=True)
plt.title("area_sqft Distribution")
plt.show()

# %%
coll
# Out:
# Index(['house_id', 'area_sqft', 'bedrooms', 'bathrooms', 'location_score',
#        'age_years', 'distance_city_km', 'lot_size_sqft', 'has_garage',
#        'has_pool', 'renovation_years_ago', 'house_price_inr'],
#       dtype='object')

# %%
from scipy.stats import boxcox

df['bedrooms'], _ = boxcox(df['bedrooms'])

sns.histplot(df["bedrooms"], kde=True)
plt.title("bedrooms Distribution")
plt.show()

# %%
from scipy.stats import boxcox

df['bathrooms'], _ = boxcox(df['bathrooms'])

sns.histplot(df["bathrooms"], kde=True)
plt.title("bathrooms Distribution")
plt.show()

# %%
from scipy.stats import boxcox

df['location_score'], _ = boxcox(df['location_score'])

sns.histplot(df["location_score"], kde=True)
plt.title("location_score Distribution")
plt.show()

# %%
from scipy.stats import boxcox

df['age_years'], _ = boxcox(df['age_years'])

sns.histplot(df["age_years"], kde=True)
plt.title("age_years Distribution")
plt.show()

# %%
coll
# Out:
# Index(['house_id', 'area_sqft', 'bedrooms', 'bathrooms', 'location_score',
#        'age_years', 'distance_city_km', 'lot_size_sqft', 'has_garage',
#        'has_pool', 'renovation_years_ago', 'house_price_inr'],
#       dtype='object')

# %%
from scipy.stats import boxcox

df['distance_city_km'], _ = boxcox(df['distance_city_km'])

sns.histplot(df["distance_city_km"], kde=True)
plt.title("distance_city_km Distribution")
plt.show()

# %%
from scipy.stats import boxcox

df['lot_size_sqft'], _ = boxcox(df['lot_size_sqft'])

sns.histplot(df["lot_size_sqft"], kde=True)
plt.title("lot_size_sqft Distribution")
plt.show()

# %%
df['renovation_years_ago'] = np.log(df['renovation_years_ago'])
sns.histplot(df["renovation_years_ago"], kde=True)
plt.title("renovation_years_ago Distribution")
plt.show()

# %%
from scipy.stats import boxcox

df['house_price_inr'], _ = boxcox(df['house_price_inr'])

sns.histplot(df["house_price_inr"], kde=True)
plt.title("house_price_inr Distribution")
plt.show()

# %%
df.head()
# Out:
#    house_id   area_sqft  bedrooms  bathrooms  location_score  age_years  \
# 0    100001  528.780883  3.135784   2.282708        6.968860   5.654612
# 1    100002  438.313019  1.709845   1.621739        5.562617   4.125656
# 2    100003  549.655509  2.445031   1.621739        5.024763   3.288380
# 3    100004  667.222029  3.135784   1.621739        7.077460   3.934248
# 4    100005  424.335180  1.709845   1.621739        2.894025   4.481321
#
#    distance_city_km  lot_size_sqft  has_garage  has_pool  \
# 0          7.744718      84.350129           1         0
# 1         10.018827      74.206278           1         0
# 2         12.932481      79.017339           0         0
# 3          5.243444      71.939447           1         1
# 4         14.461276      62.993609           0         0
#
#    renovation_years_ago  house_price_inr
# 0                  -inf     12789.861345
# 1              2.564949     10432.978821
# 2              2.197225     10909.794416
# ...

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df)
profile.to_file("realestatepostedaprocess.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 60.52it/s]

# %%
df.to_csv("Prescaledata.csv")

# %%
df.shape
# Out:
# (4200, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4200 entries, 0 to 4199
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   house_id              4200 non-null   int64
#  1   area_sqft             4200 non-null   float64
#  2   bedrooms              4200 non-null   float64
#  3   bathrooms             4200 non-null   float64
#  4   location_score        4200 non-null   float64
#  5   age_years             4200 non-null   float64
#  6   distance_city_km      4200 non-null   float64
#  7   lot_size_sqft         4200 non-null   float64
#  8   has_garage            4200 non-null   int64
#  9   has_pool              4200 non-null   int64
#  10  renovation_years_ago  4200 non-null   float64
#  11  house_price_inr       4200 non-null   float64
# dtypes: float64(9), int64(3)
# memory usage: 393.9 KB

# %%
df = df[~df.isin([np.inf, -np.inf]).any(axis=1)]

# %%
df.head()
# Out:
#    house_id   area_sqft  bedrooms  bathrooms  location_score  age_years  \
# 1    100002  438.313019  1.709845   1.621739        5.562617   4.125656
# 2    100003  549.655509  2.445031   1.621739        5.024763   3.288380
# 3    100004  667.222029  3.135784   1.621739        7.077460   3.934248
# 4    100005  424.335180  1.709845   1.621739        2.894025   4.481321
# 5    100006  424.335180  1.709845   0.000000        6.751834   3.288380
#
#    distance_city_km  lot_size_sqft  has_garage  has_pool  \
# 1         10.018827      74.206278           1         0
# 2         12.932481      79.017339           0         0
# 3          5.243444      71.939447           1         1
# 4         14.461276      62.993609           0         0
# 5          8.576511      56.190962           0         0
#
#    renovation_years_ago  house_price_inr
# 1              2.564949     10432.978821
# 2              2.197225     10909.794416
# 3              1.386294     13922.213431
# ...

# %%
df.shape
# Out:
# (3725, 12)

# %%
df["bedrooms"] = df["bedrooms"].round().astype("Int64")

# %%
df.head()
# Out:
#    house_id   area_sqft  bedrooms  bathrooms  location_score  age_years  \
# 1    100002  438.313019         2   1.621739        5.562617   4.125656
# 2    100003  549.655509         2   1.621739        5.024763   3.288380
# 3    100004  667.222029         3   1.621739        7.077460   3.934248
# 4    100005  424.335180         2   1.621739        2.894025   4.481321
# 5    100006  424.335180         2   0.000000        6.751834   3.288380
#
#    distance_city_km  lot_size_sqft  has_garage  has_pool  \
# 1         10.018827      74.206278           1         0
# 2         12.932481      79.017339           0         0
# 3          5.243444      71.939447           1         1
# 4         14.461276      62.993609           0         0
# 5          8.576511      56.190962           0         0
#
#    renovation_years_ago  house_price_inr
# 1              2.564949     10432.978821
# 2              2.197225     10909.794416
# 3              1.386294     13922.213431
# ...

# %%
df["bathrooms"] = df["bathrooms"].round().astype("Int64")

# %%
df.head()
# Out:
#    house_id   area_sqft  bedrooms  bathrooms  location_score  age_years  \
# 1    100002  438.313019         2          2        5.562617   4.125656
# 2    100003  549.655509         2          2        5.024763   3.288380
# 3    100004  667.222029         3          2        7.077460   3.934248
# 4    100005  424.335180         2          2        2.894025   4.481321
# 5    100006  424.335180         2          0        6.751834   3.288380
#
#    distance_city_km  lot_size_sqft  has_garage  has_pool  \
# 1         10.018827      74.206278           1         0
# 2         12.932481      79.017339           0         0
# 3          5.243444      71.939447           1         1
# 4         14.461276      62.993609           0         0
# 5          8.576511      56.190962           0         0
#
#    renovation_years_ago  house_price_inr
# 1              2.564949     10432.978821
# 2              2.197225     10909.794416
# 3              1.386294     13922.213431
# ...

# %%
df["bathrooms"] = df["bathrooms"].replace(0, 1)

# %%
df.head()
# Out:
#    house_id   area_sqft  bedrooms  bathrooms  location_score  age_years  \
# 1    100002  438.313019         2          2        5.562617   4.125656
# 2    100003  549.655509         2          2        5.024763   3.288380
# 3    100004  667.222029         3          2        7.077460   3.934248
# 4    100005  424.335180         2          2        2.894025   4.481321
# 5    100006  424.335180         2          1        6.751834   3.288380
#
#    distance_city_km  lot_size_sqft  has_garage  has_pool  \
# 1         10.018827      74.206278           1         0
# 2         12.932481      79.017339           0         0
# 3          5.243444      71.939447           1         1
# 4         14.461276      62.993609           0         0
# 5          8.576511      56.190962           0         0
#
#    renovation_years_ago  house_price_inr
# 1              2.564949     10432.978821
# 2              2.197225     10909.794416
# 3              1.386294     13922.213431
# ...

# %%
df["bedrooms"] = df["bedrooms"].replace(0, 1)

# %%
df["location_score"] = df["location_score"].replace(0, 1)

# %%
df.head()
# Out:
#    house_id   area_sqft  bedrooms  bathrooms  location_score  age_years  \
# 1    100002  438.313019         2          2        5.562617   4.125656
# 2    100003  549.655509         2          2        5.024763   3.288380
# 3    100004  667.222029         3          2        7.077460   3.934248
# 4    100005  424.335180         2          2        2.894025   4.481321
# 5    100006  424.335180         2          1        6.751834   3.288380
#
#    distance_city_km  lot_size_sqft  has_garage  has_pool  \
# 1         10.018827      74.206278           1         0
# 2         12.932481      79.017339           0         0
# 3          5.243444      71.939447           1         1
# 4         14.461276      62.993609           0         0
# 5          8.576511      56.190962           0         0
#
#    renovation_years_ago  house_price_inr
# 1              2.564949     10432.978821
# 2              2.197225     10909.794416
# 3              1.386294     13922.213431
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()


df["area_scaled"] = scaler.fit_transform(df[["area_sqft"]])

# %%
df.head()
# Out:
#    house_id   area_sqft  bedrooms  bathrooms  location_score  age_years  \
# 1    100002  438.313019         2          2        5.562617   4.125656
# 2    100003  549.655509         2          2        5.024763   3.288380
# 3    100004  667.222029         3          2        7.077460   3.934248
# 4    100005  424.335180         2          2        2.894025   4.481321
# 5    100006  424.335180         2          1        6.751834   3.288380
#
#    distance_city_km  lot_size_sqft  has_garage  has_pool  \
# 1         10.018827      74.206278           1         0
# 2         12.932481      79.017339           0         0
# 3          5.243444      71.939447           1         1
# 4         14.461276      62.993609           0         0
# 5          8.576511      56.190962           0         0
#
#    renovation_years_ago  house_price_inr  area_scaled
# 1              2.564949     10432.978821     0.425857
# 2              2.197225     10909.794416     0.597446
# ...

# %%
df["bedrooms_scaled"] = scaler.fit_transform(df[["bedrooms"]])
df["bathrooms_scaled"] = scaler.fit_transform(df[["bathrooms"]])
df["location_score_scaled"] = scaler.fit_transform(df[["location_score"]])
df["age_years_scaled"] = scaler.fit_transform(df[["age_years"]])
df["distance_city_km_scaled"] = scaler.fit_transform(df[["distance_city_km"]])
df["lot_size_sqft_scaled"] = scaler.fit_transform(df[["lot_size_sqft"]])
df["has_garage_scaled"] = scaler.fit_transform(df[["has_garage"]])
df["has_pool_scaled"] = scaler.fit_transform(df[["has_pool"]])
df["renovation_years_ago_scaled"] = scaler.fit_transform(df[["renovation_years_ago"]])
df["house_price_scaled"] = scaler.fit_transform(df[["house_price_inr"]])

# %%
df.head()
# Out:
#    house_id   area_sqft  bedrooms  bathrooms  location_score  age_years  \
# 1    100002  438.313019         2          2        5.562617   4.125656
# 2    100003  549.655509         2          2        5.024763   3.288380
# 3    100004  667.222029         3          2        7.077460   3.934248
# 4    100005  424.335180         2          2        2.894025   4.481321
# 5    100006  424.335180         2          1        6.751834   3.288380
#
#    distance_city_km  lot_size_sqft  has_garage  has_pool  ...  \
# 1         10.018827      74.206278           1         0  ...
# 2         12.932481      79.017339           0         0  ...
# 3          5.243444      71.939447           1         1  ...
# 4         14.461276      62.993609           0         0  ...
# 5          8.576511      56.190962           0         0  ...
#
#    bedrooms_scaled  bathrooms_scaled  location_score_scaled  age_years_scaled  \
# ...

# %%
df.to_csv("alldata.csv")

# %%
df.columns
# Out:
# Index(['house_id', 'area_sqft', 'bedrooms', 'bathrooms', 'location_score',
#        'age_years', 'distance_city_km', 'lot_size_sqft', 'has_garage',
#        'has_pool', 'renovation_years_ago', 'house_price_inr', 'area_scaled',
#        'bedrooms_scaled', 'bathrooms_scaled', 'location_score_scaled',
#        'age_years_scaled', 'distance_city_km_scaled', 'lot_size_sqft_scaled',
#        'has_garage_scaled', 'has_pool_scaled', 'renovation_years_ago_scaled',
#        'house_price_scaled'],
#       dtype='object')

# %%
scaleddata = df.drop([ 'area_sqft', 'bedrooms', 'bathrooms', 'location_score',
       'age_years', 'distance_city_km', 'lot_size_sqft', 'has_garage',
       'has_pool', 'renovation_years_ago', 'house_price_inr',], axis=1)

# %%
scaleddata.to_csv("scaleddata.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[261], line 1
# ----> 1 scaleddata.to_csv("scaleddata.csv")
#
# File e:\Rnw\dataprofiler\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File e:\Rnw\dataprofiler\Lib\site-packages\pandas\core\generic.py:3989, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
# ...
