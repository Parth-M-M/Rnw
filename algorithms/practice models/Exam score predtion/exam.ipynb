# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\parth\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"E:\Rnw\algorithms\practice models\Exam score predtion\Exam_Score_Prediction.csv")

# %%
df.head(10)
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
# 5           6   23    male   b.tech         3.48              65.4
# 6           7   17  female   b.tech         1.35              69.0
# 7           8   22    male     b.sc         5.48              51.1
# 8           9   18   other      bca         2.89              92.0
# 9          10   17    male      bba         6.77              44.8
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# ...

# %%
# !pip install sweetviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\parth\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import sweetviz as sv

report = sv.analyze(df)
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)

# %%
report.show_html('report.html')
# Out:
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df.shape
# Out:
# (20000, 13)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        20000 non-null  int64
#  1   age               20000 non-null  int64
#  2   gender            20000 non-null  str
#  3   course            20000 non-null  str
#  4   study_hours       20000 non-null  float64
#  5   class_attendance  20000 non-null  float64
#  6   internet_access   20000 non-null  str
#  7   sleep_hours       20000 non-null  float64
#  8   sleep_quality     20000 non-null  str
#  9   study_method      20000 non-null  str
#  10  facility_rating   20000 non-null  str
#  11  exam_difficulty   20000 non-null  str
#  12  exam_score        20000 non-null  float64
# dtypes: float64(4), int64(2), str(7)
# memory usage: 2.0 MB

# %%
df.describe()
# Out:
#          student_id           age   study_hours  class_attendance  \
# count  20000.000000  20000.000000  20000.000000      20000.000000
# mean   10000.504600     20.473300      4.007604         70.017365
# std     5773.654959      2.284458      2.308313         17.282262
# min        1.000000     17.000000      0.080000         40.600000
# 25%     5000.750000     18.000000      2.000000         55.100000
# 50%    10000.500000     20.000000      4.040000         69.900000
# 75%    15000.250000     22.000000      6.000000         85.000000
# max    20001.000000     24.000000      7.910000         99.400000
#
#        sleep_hours    exam_score
# count  20000.00000  20000.000000
# mean       7.00856     62.513225
# std        1.73209     18.908491
# min        4.10000     19.599000
# 25%        5.50000     48.800000
# 50%        7.00000     62.600000
# 75%        8.50000     76.300000
# max        9.90000    100.000000

# %%
df.describe(include = object)
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_14924\2598962911.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include = object)
#        gender course internet_access sleep_quality study_method  \
# count   20000  20000           20000         20000        20000
# unique      3      7               2             3            5
# top     other    bca             yes       average   self-study
# freq     6726   2902           16988          6694         4079
#
#        facility_rating exam_difficulty
# count            20000           20000
# ...

# %%
df.isnull().sum()
# Out:
# student_id          0
# age                 0
# gender              0
# course              0
# study_hours         0
# class_attendance    0
# internet_access     0
# sleep_hours         0
# sleep_quality       0
# study_method        0
# facility_rating     0
# exam_difficulty     0
# exam_score          0
# dtype: int64

# %%
dtr_coll = df.select_dtypes(include=['object', 'string']).columns

# %%
encoders = {}
for col in dtr_coll:
    le = LabelEncoder()
    encoders[col] = le
    df[col + "_encoded"] = le.fit_transform(df[col])

# %%
encoders
# Out:
# {'gender': LabelEncoder(),
#  'course': LabelEncoder(),
#  'internet_access': LabelEncoder(),
#  'sleep_quality': LabelEncoder(),
#  'study_method': LabelEncoder(),
#  'facility_rating': LabelEncoder(),
#  'exam_difficulty': LabelEncoder()}

# %%
for col in dtr_coll:
    print(f"Mapping for '{col}': {dict(zip(encoders[col].classes_, range(len(encoders[col].classes_))))}")
# Out:
# Mapping for 'gender': {'female': 0, 'male': 1, 'other': 2}
# Mapping for 'course': {'b.com': 0, 'b.sc': 1, 'b.tech': 2, 'ba': 3, 'bba': 4, 'bca': 5, 'diploma': 6}
# Mapping for 'internet_access': {'no': 0, 'yes': 1}
# Mapping for 'sleep_quality': {'average': 0, 'good': 1, 'poor': 2}
# Mapping for 'study_method': {'coaching': 0, 'group study': 1, 'mixed': 2, 'online videos': 3, 'self-study': 4}
# Mapping for 'facility_rating': {'high': 0, 'low': 1, 'medium': 2}
# Mapping for 'exam_difficulty': {'easy': 0, 'hard': 1, 'moderate': 2}

# %%
numeric_cols = df.select_dtypes(include=['number']).columns

for i in numeric_cols:
    plt.figure() 
    plt.boxplot(df[i].dropna()) 
    plt.xlabel(i)
    plt.ylabel('count')
    plt.show()

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()
