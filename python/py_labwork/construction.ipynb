# %%
import math

def selector(no):
    if 0 < no <= 3:
        return 0.25
    elif 3 < no <= 6:
        return 0.5
    elif 6 < no <= 9:
        return 0.75
    elif 9 < no <= 12:
        return 1
    else:
        return 0
    
print("== Enter length of footing ==")
length_foot = int(input("Enter foot : "))
length_inch = int(input("Enter inch : "))
print("== Enter breath of footing ==")
breath_foot = int(input("Enter foot : "))
breath_inch = int(input("Enter inch : "))
print("== Enter spacing of footing ==")
mm_center = int(input("Enter center : "))
print("== Enter thickness of rod ==")
rod_mm = int(input("Enter rod mm : "))
print("== top & bottom mesh ==")
mesh = int(input("Enter no of mesh : "))
print("== total no of footing ==")
no_of_footing = int(input("Enter total no of footing : "))

non_length = selector(length_inch)
non_breath = selector(breath_inch)
total_length_foot = length_foot + non_length
total_breath_foot = breath_foot + non_breath
total_length_inch = (length_foot * 12) + length_inch
total_breath_inch = (breath_foot * 12) + breath_inch

length_spacing = math.ceil(total_length_inch / mm_center)
breath_spacing = math.ceil(total_breath_inch / mm_center)

no_of_rod_on_length = length_spacing * total_breath_foot
no_of_rod_on_breath = breath_spacing * total_length_foot

total = no_of_rod_on_breath + no_of_rod_on_length 

total_top_bottom = total * mesh

total_footing = total_top_bottom * no_of_footing

no_of_rod = math.ceil(total_footing / 39)

total_footing_weight = math.ceil((((rod_mm*rod_mm)/162)*12)*no_of_rod)
# Optional: Print results
print("Length Spacing (in rods):", length_spacing)
print("Breath Spacing (in rods):", breath_spacing)
print("Number of rods along length:", no_of_rod_on_length)
print("Number of rods along breath:", no_of_rod_on_breath)
print("total length of rod :",total)
print("total mesh :",total_top_bottom,"ft")
print("total footing :",total_footing,"ft")
print("no of rods :",no_of_rod)
print("total footing wieght :", total_footing_weight,"kg")
# Out:
# == Enter length of footing ==
# == Enter breath of footing ==
# == Enter spacing of footing ==
# == Enter thickness of rod ==
# == top & bottom mesh ==
# == total no of footing ==
# Length Spacing (in rods): 18
# Breath Spacing (in rods): 20
# Number of rods along length: 144
# Number of rods along breath: 150.0
# total length of rod : 294.0
# total mesh : 588.0 ft
# total footing : 1176.0 ft
# no of rods : 31
# total footing wieght : 58 kg

# %%
import math

def weightfinder(mm,trod):
    return math.ceil((((mm*mm)/162)*12)*trod)

colunm_length = int(input("Enter colunm length in inch"))
colunm_bredth = int(input("Enter colunm breadth in inch"))
total_colunm_of_this_type = int(input("Enter total no of colunm of this type"))
total_hight_of_colonm = float(input("Enter total heigth of the colunm"))*12
center_of_rings = float(input("Enter center of rings"))
total_no_of_ring_per_colunm = total_hight_of_colonm / center_of_rings

total_type_of_rings = int(input("enter total type rings used in colunm : "))
if total_type_of_rings == 1 :
    thickness_of_ring = int(input("Enter thickness of the ring  :"))
    length_of_ring_1 = int(input("enter length of ring 1 : "))+2
    breath_of_ring_1 = int(input("enter breath of ring 1: "))+2
    total_ring_type_1 = int(input("total number of ring type 1 : "))
    perimeter_of_type_ring_1 = ((length_of_ring_1 * 2) + (breath_of_ring_1 * 2)) - 4
    total_perimeter = perimeter_of_type_ring_1
elif total_type_of_rings == 2 :
    thickness_of_ring = int(input("Enter thickness of the ring  :"))
    length_of_ring_1 = int(input("enter length of ring 1 : "))+2
    breath_of_ring_1 = int(input("enter breath of ring 1: "))+2
    total_ring_type_1 = int(input("total number of ring type 1 : "))
    length_of_ring_2 = int(input("enter length of ring 2 : "))+2
    breath_of_ring_2 = int(input("enter breath of ring 2: "))+2
    total_ring_type_2 = int(input("total number of ring type 2 : "))
    perimeter_of_type_ring_1 = ((length_of_ring_1 * 2) + (breath_of_ring_1 * 2)) - 4
    perimeter_of_type_ring_2 = ((length_of_ring_2 * 2) + (breath_of_ring_2 * 2)) - 4
    total_perimeter = perimeter_of_type_ring_1 * total_ring_type_1 + perimeter_of_type_ring_2 * total_ring_type_2
elif total_type_of_rings == 3 :
    thickness_of_ring = int(input("Enter thickness of the ring  :"))
    length_of_ring_1 = int(input("enter length of ring 1 : "))+2
    breath_of_ring_1 = int(input("enter breath of ring 1: "))+2
    total_ring_type_1 = int(input("total number of ring type 1 : "))
    length_of_ring_2 = int(input("enter length of ring 2 : "))+2
    breath_of_ring_2 = int(input("enter breath of ring 2: "))+2
    total_ring_type_2 = int(input("total number of ring type 2 : "))
    length_of_ring_3 = int(input("enter length of ring 3 : "))+2
    breath_of_ring_3 = int(input("enter breath of ring 3: "))+2
    total_ring_type_3 = int(input("total number of ring type 3 : "))
    perimeter_of_type_ring_1 = ((length_of_ring_1 * 2) + (breath_of_ring_1 * 2)) - 4
    perimeter_of_type_ring_2 = ((length_of_ring_2 * 2) + (breath_of_ring_2 * 2)) - 4
    perimeter_of_type_ring_3 = ((length_of_ring_3 * 2) + (breath_of_ring_3 * 2)) - 4
    total_perimeter = perimeter_of_type_ring_1 *total_ring_type_1 + perimeter_of_type_ring_2*total_ring_type_2 + perimeter_of_type_ring_3*total_ring_type_3
elif total_type_of_rings == 4 :
    thickness_of_ring = int(input("Enter thickness of the ring  :"))
    length_of_ring_1 = int(input("enter length of ring 1 : "))+2
    breath_of_ring_1 = int(input("enter breath of ring 1: "))+2
    total_ring_type_1 = int(input("total number of ring type 1 : "))
    length_of_ring_2 = int(input("enter length of ring 2 : "))+2
    breath_of_ring_2 = int(input("enter breath of ring 2: "))+2
    total_ring_type_2 = int(input("total number of ring type 2 : "))
    length_of_ring_3 = int(input("enter length of ring 3 : "))+2
    breath_of_ring_3 = int(input("enter breath of ring 3: "))+2
    total_ring_type_3 = int(input("total number of ring type 3 : "))
    length_of_ring_4 = int(input("enter length of ring 4 : "))+2
    breath_of_ring_4 = int(input("enter breath of ring 4: "))+2
    total_ring_type_4 = int(input("total number of ring type 4 : "))
    perimeter_of_type_ring_1 = ((length_of_ring_1 * 2) + (breath_of_ring_1 * 2)) - 4
    perimeter_of_type_ring_2 = ((length_of_ring_2 * 2) + (breath_of_ring_2 * 2)) - 4
    perimeter_of_type_ring_3 = ((length_of_ring_3 * 2) + (breath_of_ring_3 * 2)) - 4
    perimeter_of_type_ring_4 = ((length_of_ring_4 * 2) + (breath_of_ring_4 * 2)) - 4
    total_perimeter = perimeter_of_type_ring_1*total_ring_type_1 + perimeter_of_type_ring_2*total_ring_type_2 +perimeter_of_type_ring_3*total_ring_type_3+perimeter_of_type_ring_4*total_ring_type_4
elif total_type_of_rings == 5 :
    thickness_of_ring = int(input("Enter thickness of the ring  :"))
    length_of_ring_1 = int(input("enter length of ring 1 : "))+2
    breath_of_ring_1 = int(input("enter breath of ring 1: "))+2
    total_ring_type_1 = int(input("total number of ring type 1 : "))
    length_of_ring_2 = int(input("enter length of ring 2 : "))+2
    breath_of_ring_2 = int(input("enter breath of ring 2: "))+2
    total_ring_type_2 = int(input("total number of ring type 2 : "))
    length_of_ring_3 = int(input("enter length of ring 3 : "))+2
    breath_of_ring_3 = int(input("enter breath of ring 3: "))+2
    total_ring_type_3 = int(input("total number of ring type 3 : "))
    length_of_ring_4 = int(input("enter length of ring 4 : "))+2
    breath_of_ring_4 = int(input("enter breath of ring 4: "))+2
    total_ring_type_4 = int(input("total number of ring type 4 : "))
    length_of_ring_5 = int(input("enter length of ring 5 : "))+2
    breath_of_ring_5 = int(input("enter breath of ring 5: "))+2
    total_ring_type_5 = int(input("total number of ring type 5 : "))
    perimeter_of_type_ring_1 = ((length_of_ring_1 * 2) + (breath_of_ring_1 * 2)) - 4
    perimeter_of_type_ring_2 = ((length_of_ring_2 * 2) + (breath_of_ring_2 * 2)) - 4
    perimeter_of_type_ring_3 = ((length_of_ring_3 * 2) + (breath_of_ring_3 * 2)) - 4
    perimeter_of_type_ring_4 = ((length_of_ring_4 * 2) + (breath_of_ring_4 * 2)) - 4
    perimeter_of_type_ring_5 = ((length_of_ring_5 * 2) + (breath_of_ring_5 * 2)) - 4
    total_perimeter = perimeter_of_type_ring_1*total_ring_type_1+perimeter_of_type_ring_2*total_ring_type_2+perimeter_of_type_ring_3*total_ring_type_3+perimeter_of_type_ring_4*total_ring_type_4+perimeter_of_type_ring_5*total_ring_type_5


else :
    print("Exeded the calculation limit")

super_total_length_of_ring = total_perimeter * total_no_of_ring_per_colunm
super_total_length_of_ring_in_foot = math.ceil(super_total_length_of_ring / 12)
super_total_of_rod = math.ceil(super_total_length_of_ring_in_foot / 39)
total_weigth = weightfinder(thickness_of_ring,super_total_of_rod) * total_colunm_of_this_type
print(total_weigth)
# Out:
# 315

# %%
total_type_of_rod = int(input("Enter total type of rod used in colunm "))
if total_type_of_rod == 1 :
    colunm_steel_1 = int((input("Enter number of steel type 1 bar in colunm : ")))
    colunm_steel_1_mm = int(input("Enter your steel type 1 bar thichness in mm : "))
elif total_type_of_rod == 2 :
    colunm_steel_1 = int((input("Enter number of steel type 1 bar in colunm : ")))
    colunm_steel_1_mm = int(input("Enter your steel type 1 bar thichness in mm : "))
    colunm_steel_2 = int((input("Enter number of steel type 2 bar in colunm : ")))
    colunm_steel_2_mm = int(input("Enter your steel type 2 bar thichness in mm : "))
elif total_type_of_rod == 3 :
    colunm_steel_1 = int((input("Enter number of steel type 1 bar in colunm : ")))
    colunm_steel_1_mm = int(input("Enter your steel type 1 bar thichness in mm : "))
    colunm_steel_2 = int((input("Enter number of steel type 2 bar in colunm : ")))
    colunm_steel_2_mm = int(input("Enter your steel type 2 bar thichness in mm : "))
    colunm_steel_3 = int((input("Enter number of steel type 3 bar in colunm : ")))
    colunm_steel_3_mm = int(input("Enter your steel type 3 bar thichness in mm : "))

elif total_type_of_rod == 4 :
    colunm_steel_1 = int((input("Enter number of steel type 1 bar in colunm : ")))
    colunm_steel_1_mm = int(input("Enter your steel type 1 bar thichness in mm : "))
    colunm_steel_2 = int((input("Enter number of steel type 2 bar in colunm : ")))
    colunm_steel_2_mm = int(input("Enter your steel type 2 bar thichness in mm : "))
    colunm_steel_3 = int((input("Enter number of steel type 3 bar in colunm : ")))
    colunm_steel_3_mm = int(input("Enter your steel type 3 bar thichness in mm : "))
    colunm_steel_4 = int((input("Enter number of steel type 4 bar in colunm : ")))
    colunm_steel_4_mm = int(input("Enter your steel type 4 bar thichness in mm : "))
else :
    print("Exeded the calculation limit")

# %%
no_of_colunm = int(input("enter number of colunm"))
thickness = float(input("enter pcc  thickness"))
length_foot = int(input("Enter your length foot : "))
length_inch = int(input("enter your length inch "))
total_length_in_inch = (length_foot * 12)+ length_inch
breadth_foot = int(input("enter your breath foot"))
bredth_inch = int(input("enter your breath inch"))
total_bredth_in_inch = (breadth_foot*12)+bredth_inch
cube_inch = math.ceil(total_bredth_in_inch * total_length_in_inch * thickness)
cube_meter = cube_inch/61020
total_cubic_meter = cube_meter *no_of_colunm
print(cube_inch)
print(cube_meter)
print(total_cubic_meter)
# Out:
# 541728
# 8.877876106194691
# 17.755752212389382

# %%
! pip install pydub
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! python.exe -m pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 1.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 1.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 1.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# ...

# %%
from pydub import AudioSegment, effects

# === Input and Output Paths ===
input_path = "SATSANG 1.mp3"           # Replace with your file name
output_path = "SATSANG_1_filtered.mp3" # Output file

# === Load Audio ===
audio = AudioSegment.from_file(input_path, format="mp3")

# === Apply Filters ===
# Remove low-frequency hum (below ~150Hz)
filtered = audio.high_pass_filter(150)

# Remove high-frequency hiss (above ~8000Hz)
filtered = filtered.low_pass_filter(8000)

# Normalize volume for clarity
filtered = effects.normalize(filtered)

# === Export Processed Audio ===
filtered.export(output_path, format="mp3")

print(f"Filtered audio saved as {output_path}")

# %%
import numpy as np
from scipy.stats import norm

# Hypothetical values
population_mean = 170     # μ₀
population_std = 10       # σ (known)
sample = np.random.normal(loc=172, scale=10, size=100)  # Sample data

# Step 1: Calculate sample mean and size
sample_mean = np.mean(sample)
n = len(sample)

# Step 2: Calculate z-score
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(n))

# Step 3: Calculate p-value (two-tailed)
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Step 4: Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.4f}")

# Step 5: Conclusion
alpha = 0.05
if p_value < alpha:
    print("Reject the Null Hypothesis (significant difference).")
else:
    print("Fail to Reject the Null Hypothesis (no significant difference).")
# Out:
# Sample Mean: 171.81
# Z-score: 1.81
# P-value: 0.0706
# Fail to Reject the Null Hypothesis (no significant difference).
